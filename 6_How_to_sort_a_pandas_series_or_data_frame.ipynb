# %% [markdown]
# # How to sort a pandas series or data frame

# %%
import pandas as pd

# %%
movies = pd.read_csv('http://bit.ly/imdbratings')

# %%
movies
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
# Sorting the title series
movies.title.sort_values(ascending=False)
# Out:
# 864                    [Rec]
# 526                     Zulu
# 615               Zombieland
# 677                   Zodiac
# 955         Zero Dark Thirty
#                ...
# 110    2001: A Space Odyssey
# 698                127 Hours
# 201         12 Years a Slave
# 5               12 Angry Men
# 542     (500) Days of Summer
# Name: title, Length: 979, dtype: object

# %%
# Using bracket notation
movies['title'].sort_values()
# Out:
# 542     (500) Days of Summer
# 5               12 Angry Men
# 201         12 Years a Slave
# 698                127 Hours
# 110    2001: A Space Odyssey
#                ...
# 955         Zero Dark Thirty
# 677                   Zodiac
# 615               Zombieland
# 526                     Zulu
# 864                    [Rec]
# Name: title, Length: 979, dtype: object

# %%
# Sorting the entire movies data frame by the column title
movies.sort_values(by = 'title',ascending=True,inplace=True)
movies
# Out:
#      star_rating                  title content_rating      genre  duration  \
# 542          7.8   (500) Days of Summer          PG-13     Comedy        95
# 5            8.9           12 Angry Men      NOT RATED      Drama        96
# 201          8.1       12 Years a Slave              R  Biography       134
# 698          7.6              127 Hours              R  Adventure        94
# 110          8.3  2001: A Space Odyssey              G    Mystery       160
# ..           ...                    ...            ...        ...       ...
# 955          7.4       Zero Dark Thirty              R      Drama       157
# 677          7.7                 Zodiac              R      Crime       157
# 615          7.7             Zombieland              R     Comedy        88
# 526          7.8                   Zulu        UNRATED      Drama       138
# 864          7.5                  [Rec]              R     Horror        78
#
#                                            actors_list
# ...

# %%
# Sorting the entire movies data frame by the column genre first and then title
movies.sort_values(by = ['genre','title'],ascending=True,inplace=True)
movies
# Out:
#      star_rating                           title content_rating    genre  \
# 570          7.8                             300              R   Action
# 276          8.1            A Fistful of Dollars              R   Action
# 75           8.4                          Aliens              R   Action
# 529          7.8                      Apocalypto              R   Action
# 433          7.9                          Avatar          PG-13   Action
# ..           ...                             ...            ...      ...
# 26           8.6    Once Upon a Time in the West          PG-13  Western
# 263          8.1                       Rio Bravo      NOT RATED  Western
# 6            8.9  The Good, the Bad and the Ugly      NOT RATED  Western
# 421          7.9          The Outlaw Josey Wales             PG  Western
# 119          8.3                      Unforgiven              R  Western
#
#      duration                                        actors_list
# ...
